# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Sales data Tablue.xlsx")

# %%
df
# Out:
#                         Region               Country   Item_Type  \
# 0             Central America   Antigua and Barbuda    Baby Food
# 1             Central America                 Panama      Snacks
# 2                       Europe        Czech Republic   Beverages
# 3                         Asia           North Korea      Cereal
# 4                         Asia             Sri Lanka      Snacks
# ...                        ...                   ...         ...
# 4995         Australia/Oceania           New Zealand  Vegetables
# 4996  Middle East/North Africa            Azerbaijan      Snacks
# 4997                      Asia               Myanmar   Baby Food
# 4998                    Europe               Finland     Clothes
# 4999        Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority           Order_Date  Year   Order_ID  \
# 0           Online              M           12/20/2013  2013  957081544
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 547.0+ KB

# %%
df.isnull().sum()
# Out:
# Region               0
# Country              0
# Item_Type            0
# Sales_Channel        0
# Order_Priority       0
# Order_Date           0
# Year                 0
# Order_ID             0
# Ship_Date            0
# Units_Sold           0
# Unit_SellingPrice    0
# Unit_MakingCost      0
# unit_per Profit      0
# Total profit         0
# dtype: int64

# %%
df.head()
# Out:
#              Region               Country  Item_Type Sales_Channel  \
# 0  Central America   Antigua and Barbuda   Baby Food        Online
# 1  Central America                 Panama     Snacks       Offline
# 2            Europe        Czech Republic  Beverages       Offline
# 3              Asia           North Korea     Cereal       Offline
# 4              Asia             Sri Lanka     Snacks       Offline
#
#   Order_Priority           Order_Date  Year   Order_ID            Ship_Date  \
# 0              M           12/20/2013  2013  957081544  2014-11-01 00:00:00
# 1              C  2010-05-07 00:00:00  2010  301644504            7/26/2010
# 2              C  2011-12-09 00:00:00  2011  478051030            9/29/2011
# 3              L            5/13/2010  2010  892599952            6/15/2010
# 4              C            7/20/2015  2015  571902596            7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  unit_per Profit  \
# ...

# %%
df["Total_cost"] = df["Units_Sold"]*df["Unit_MakingCost"]

# %%
df["Total_sales"] = df["Units_Sold"]*df["Unit_SellingPrice"]

# %% [markdown]
# # Data Visualization

# %%
print(df["Item_Type"].value_counts())
print(df["Item_Type"].value_counts().plot.bar())
# Out:
# Item_Type
# Beverages          448
# Fruits             448
# Baby Food          446
# Cosmetics          423
# Household          422
# Office Supplies    421
# Personal Care      414
# Vegetables         410
# Snacks             400
# Meat               399
# Cereal             385
# Clothes            384
# Name: count, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Region"].value_counts())
print(df["Region"].value_counts().plot.bar())
# Out:
# Region
# Europe                      1330
# Sub-Saharan Africa          1285
# Asia                         719
# Middle East/North Africa     610
# Central America              534
# Australia/Oceania            416
# North America                106
# Name: count, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Country"].value_counts())
print(df["Country"].value_counts().plot.bar())
# Out:
# Country
# San Marino                  40
# Andorra                     40
# Ghana                       38
# Mauritius                   38
# United States of America    38
#                             ..
# Dominica                    18
# Angola                      16
# Mongolia                    15
# Cape Verde                  14
# Monaco                      13
# Name: count, Length: 185, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Sales_Channel"].value_counts())
print(df["Sales_Channel"].value_counts().plot.bar())
# Out:
# Sales_Channel
# Offline    2504
# Online     2496
# Name: count, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Order_Date"].value_counts())
print(df["Order_Date"].value_counts().plot.bar())
# Out:
# Order_Date
# 6/26/2010              7
# 2/13/2011              7
# 2011-09-11 00:00:00    6
# 3/21/2014              6
# 7/24/2012              6
#                       ..
# 2/20/2013              1
# 7/18/2017              1
# 7/16/2011              1
# 12/16/2015             1
# 8/17/2014              1
# Name: count, Length: 2305, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Order_Priority"].value_counts())
print(df["Order_Priority"].value_counts().plot.bar())
# Out:
# Order_Priority
# M    1321
# H    1278
# L    1227
# C    1174
# Name: count, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df["Ship_Date"].value_counts())
print(df["Ship_Date"].value_counts().plot.bar())
# Out:
# Ship_Date
# 2016-12-06 00:00:00    7
# 3/15/2010              7
# 7/28/2014              7
# 10/21/2011             7
# 2016-01-09 00:00:00    6
#                       ..
# 6/18/2012              1
# 6/29/2012              1
# 2/27/2014              1
# 2010-07-03 00:00:00    1
# 2011-07-08 00:00:00    1
# Name: count, Length: 2320, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
plt.bar(df["Sales_Channel"],
        df["Total profit"])
plt.show()

# %%
df.groupby("Country")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.head(20)
# Out:
#                       Region                           Country  \
# 0           Central America               Antigua and Barbuda
# 1           Central America                             Panama
# 2                     Europe                    Czech Republic
# 3                       Asia                       North Korea
# 4                       Asia                         Sri Lanka
# 5   Middle East/North Africa                           Morocco
# 6          Australia/Oceania    Federated States of Micronesia
# 7                     Europe            Bosnia and Herzegovina
# 8   Middle East/North Africa                       Afghanistan
# 9         Sub-Saharan Africa                          Ethiopia
# 10  Middle East/North Africa                            Turkey
# 11  Middle East/North Africa                              Oman
# 12                      Asia                          Malaysia
# 13          Central America                        Saint Lucia
# ...

# %%
df.groupby("Country")["Total_cost"].sum().head(20).plot.bar()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
#  14  Total_cost         5000 non-null   float64
#  15  Total_sales        5000 non-null   float64
# ...

# %%
df.groupby("Country")["Total_sales"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["unit_per Profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["Unit_MakingCost"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["Unit_SellingPrice"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["Units_Sold"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["Order_ID"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Country")["Year"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Item_Type")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Sales_Channel")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Priority")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Date")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Ship_Date")["Total profit"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Item_Type")["Total_cost"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Sales_Channel")["Total_cost"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Priority")["Total_cost"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Date")["Total_cost"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Item_Type")["Total_sales"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Sales_Channel")["Total_sales"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Priority")["Total_sales"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Order_Date")["Total_sales"].sum().head(20).plot.bar()
plt.show()

# %%
df.groupby("Ship_Date")["Total_sales"].sum().head(20).plot.bar()
plt.show()
